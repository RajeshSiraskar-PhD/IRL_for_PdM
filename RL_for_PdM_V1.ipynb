# %% [markdown]
# ## RL for PdM - PhD Thesis work
#
# **Approach**
# - V.1.0 11-Aug-2024:
# - Create two environments: PHM and NUAA
# - To demonstrate robustness - Use multiple data sets from each 3 + 3 = 6
# - Additional: Add noise and Break-down
# - Publish results

# %%
import warnings
from tqdm import tqdm # Progress bar
from datetime import datetime
warnings.filterwarnings('ignore')

# General libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

# RL libraries
import gymnasium as gym
from stable_baselines3.common.env_checker import check_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3 import PPO, A2C
from stable_baselines3.ppo import MlpPolicy
from torch.utils.tensorboard import SummaryWriter

# Custom libraries
from MT_environment import MillingTool_Env_PHM,  MillingTool_Env_NUAA 
from utilities import downsample, tool_wear_data

now = datetime.now()
dt_string = now.strftime("%d-%b-%Y  %H:%M:%S")

# %%
DATA_FILE = 'NUAA_W1_0p229.csv'
WEAR_THRESHOLD = 0.229
SAMPLING_RATE = 440 # 44 for 1000 recs. 440 for 100 rec.
ADD_NOISE = 0

# DATA_FILE = 'PHM_C01.csv'
# WEAR_THRESHOLD = 0.12
# SAMPLING_RATE = 1
# ADD_NOISE = 0

ALGO = 'A2C'
EPISODES = 100
BATCH_SIZE = 16
EVALUATION_ROUNDS = 4
TENSOR_BOARD = True

PRETRAINED_MODEL = False # If True load model. If False save as model_file 
PATH = 'D:/ResearchLab/IRL/IRL_for_PdM'
MODEL_FILE = f'{PATH}/models/Agent_{ALGO}'
LOG_PATH = f'{PATH}/tensorboard/'
# LOG_PATH = f'{PATH}/tensorboard/{now.strftime("%d-%b-%Y_%H_%M")}/'

writer = SummaryWriter(LOG_PATH) if TENSOR_BOARD else None 
print(f'Tensorboard logging to {LOG_PATH}')
# Out:
# Tensorboard logging to D:/ResearchLab/IRL/IRL_for_PdM/tensorboard/

# %%
tool_wear, action_code, WEAR_THRESHOLD_NORMALIZED, df_train = tool_wear_data(
    data_file=DATA_FILE, wear_threshold = WEAR_THRESHOLD,
    normalize=True, add_noise=ADD_NOISE, sampling_rate = SAMPLING_RATE)

records = len(df_train.index)
MILLING_OPERATIONS_MAX = records

# rul_threshold_record = int(0.95 * records)
# rul_threshold = df_train.loc[df_train.index[rul_threshold_record], 'RUL']
# print(f'Tool failure RUL threshold at time {rul_threshold_record} is {rul_threshold:3.3f}')
# Out:
# - Down-sampling. Input data records: 44029. Sampling rate: 440. Expected rows 100.    Down-sampled to 101 rows.

# %%
DATA_FILE
# Out:
# 'NUAA_W1_0p229.csv'

# %% [markdown]
# ## 1. Predictive maintenance environment

# %%
from stable_baselines3.common.env_checker import check_env

gym.register(
    id = 'custom/MillingToolEnv-v0',
    entry_point = MillingTool_Env_NUAA,
    max_episode_steps = MILLING_OPERATIONS_MAX,
)

mt_env = gym.make('custom/MillingToolEnv-v0', records=records, rul_threshold=rul_threshold)
# Check env. formation 
check_env(mt_env)
# Out:
#  -- Milling tool environment initiatlized. Potential records 101. RUL threshold 0.050

# %%
mt_env.tool_wear_data(df_train)
# Out:
#  - Milling tool environment: Tool wear data updated: 101

# %% [markdown]
# ## 2. Train the PdM Agent

# %%
if ALGO == 'PPO':
    if TENSOR_BOARD:
        expert_ppo = PPO('MlpPolicy', env=mt_env, tensorboard_log=LOG_PATH)
    else:
        expert_ppo = PPO('MlpPolicy', env=mt_env)
    
    if not PRETRAINED_MODEL:
        print(f'- Training a *NEW* {ALGO} Expert model...')
        expert_ppo.learn(EPISODES)
        print(f'- Saving Expert model in {MODEL_FILE}')
        expert_ppo.save(MODEL_FILE)
    else:
        print(f'- Loading pre-tranined {ALGO} Expert model from {MODEL_FILE}')
        expert_ppo = PPO.load(MODEL_FILE)
elif ALGO == 'A2C':
    if TENSOR_BOARD:
        expert_a2c = A2C('MlpPolicy', env=mt_env, tensorboard_log=LOG_PATH)
    else:
        expert_a2c = A2C('MlpPolicy', env=mt_env)
    
    if not PRETRAINED_MODEL:
        print(f'- Training a *NEW* {ALGO} Expert model...')
        expert_a2c.learn(EPISODES)
        print(f'- Saving Expert model in {MODEL_FILE}')
        expert_a2c.save(MODEL_FILE)
    else:
        print(f'- Loading pre-tranined {ALGO} Expert model from {MODEL_FILE}')
        expert_a2c = A2C.load(MODEL_FILE)
# Out:
# - Training a *NEW* A2C Expert model...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RUL'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[31], line 23
#      21 if not PRETRAINED_MODEL:
#      22     print(f'- Training a *NEW* {ALGO} Expert model...')
# ---> 23     expert_a2c.learn(EPISODES)
#      24     print(f'- Saving Expert model in {MODEL_FILE}')
#      25     expert_a2c.save(MODEL_FILE)
#
# File ~\anaconda3\envs\RL\lib\site-packages\stable_baselines3\a2c\a2c.py:201, in A2C.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     192 def learn(
#     193     self: SelfA2C,
#     194     total_timesteps: int,
#    (...)
#     199     progress_bar: bool = False,
#     200 ) -> SelfA2C:
# --> 201     return super().learn(
#     202         total_timesteps=total_timesteps,
#     203         callback=callback,
#     204         log_interval=log_interval,
#     205         tb_log_name=tb_log_name,
#     206         reset_num_timesteps=reset_num_timesteps,
#     207         progress_bar=progress_bar,
#     208     )
#
# File ~\anaconda3\envs\RL\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:277, in OnPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     274 assert self.env is not None
#     276 while self.num_timesteps < total_timesteps:
# --> 277     continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     279     if not continue_training:
#     280         break
#
# File ~\anaconda3\envs\RL\lib\site-packages\stable_baselines3\common\on_policy_algorithm.py:194, in OnPolicyAlgorithm.collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     189     else:
#     190         # Otherwise, clip the actions to avoid out of bound error
#     191         # as we are sampling from an unbounded Gaussian distribution
#     192         clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
# --> 194 new_obs, rewards, dones, infos = env.step(clipped_actions)
#     196 self.num_timesteps += env.num_envs
#     198 # Give access to local variables
#
# File ~\anaconda3\envs\RL\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~\anaconda3\envs\RL\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~\anaconda3\envs\RL\lib\site-packages\stable_baselines3\common\monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~\anaconda3\envs\RL\lib\site-packages\gymnasium\wrappers\time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~\anaconda3\envs\RL\lib\site-packages\gymnasium\wrappers\order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~\anaconda3\envs\RL\lib\site-packages\gymnasium\wrappers\env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File D:\ResearchLab\IRL\IRL_for_PdM\MT_environment.py:154, in MillingTool_Env_NUAA.step(self, action)
#     152 info = {'Step':'-'}
#     153 # Get auxilliary info: current RUL reading (note this is NOT part of the observation) and the expert's recommended action
# --> 154 recommended_action, self.rul = self._get_auxilliary_info()
#     155 self.maintenance_cost = 0.0
#     156 self.replacement_events += 0
#
# File D:\ResearchLab\IRL\IRL_for_PdM\MT_environment.py:113, in MillingTool_Env_NUAA._get_auxilliary_info(self)
#     110 if (self.df is not None):
#     111     # From database extract recommended action
#     112     recommended_action = int(self.df.loc[self.current_time_step, 'ACTION_CODE'])
# --> 113     rul =  float(self.df.loc[self.current_time_step, 'RUL'])
#     114 else:
#     115     # No database - use dummy values
#     116     recommended_action = 0
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\indexing.py:1280, in _LocIndexer._getitem_tuple(self, tup)
#    1278 with suppress(IndexingError):
#    1279     tup = self._expand_ellipsis(tup)
# -> 1280     return self._getitem_lowerdim(tup)
#    1282 # no multi-index, so validate all of the indexers
#    1283 tup = self._validate_tuple_indexer(tup)
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\indexing.py:1000, in _LocationIndexer._getitem_lowerdim(self, tup)
#     996 for i, key in enumerate(tup):
#     997     if is_label_like(key):
#     998         # We don't need to check for tuples here because those are
#     999         #  caught by the _is_nested_tuple_indexer check above.
# -> 1000         section = self._getitem_axis(key, axis=i)
#    1002         # We should never have a scalar section here, because
#    1003         #  _getitem_lowerdim is only called after a check for
#    1004         #  is_scalar_access, which that would be.
#    1005         if section.ndim == self.ndim:
#    1006             # we're in the middle of slicing through a MultiIndex
#    1007             # revise the key wrt to `section` by inserting an _NS
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
#    1341 # fall thru to straight lookup
#    1342 self._validate_key(key, axis)
# -> 1343 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\indexing.py:1293, in _LocIndexer._get_label(self, label, axis)
#    1291 def _get_label(self, label, axis: AxisInt):
#    1292     # GH#5567 this will fail if the label is not present in the axis.
# -> 1293     return self.obj.xs(label, axis=axis)
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\generic.py:4082, in NDFrame.xs(self, key, axis, level, drop_level)
#    4080 if axis == 1:
#    4081     if drop_level:
# -> 4082         return self[key]
#    4083     index = self.columns
#    4084 else:
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'RUL'

# %%
print('-'*120)
print(' **** Reinforcement Learning for Predictive Maintenance ****')
print('-'*120)

print(dt_string)
print(f'Algo. {ALGO} - Episodes:  {EPISODES}')

if ALGO == 'PPO':
    reward_ppo, _ = evaluate_policy(expert_ppo, mt_env, 5)
    print(f'PPO agent: {reward_ppo:5.2f}')
elif ALGO == 'A2C':
    reward_a2c, _ = evaluate_policy(expert_a2c, mt_env, 20)
    print(f'A2C agent: {reward_a2c:5.2f}')
# Out:
# ------------------------------------------------------------------------------------------------------------------------
#  **** Reinforcement Learning for Predictive Maintenance ****
# ------------------------------------------------------------------------------------------------------------------------
# 12-Oct-2024  13:57:17
# Algo. A2C - Episodes:  100
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'RUL'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 12
#      10     print(f'PPO agent: {reward_ppo:5.2f}')
#      11 elif ALGO == 'A2C':
# ---> 12     reward_a2c, _ = evaluate_policy(expert_a2c, mt_env, 20)
#      13     print(f'A2C agent: {reward_a2c:5.2f}')
#
# File ~\anaconda3\envs\RL\lib\site-packages\stable_baselines3\common\evaluation.py:94, in evaluate_policy(model, env, n_eval_episodes, deterministic, render, callback, reward_threshold, return_episode_rewards, warn)
#      87 while (episode_counts < episode_count_targets).any():
#      88     actions, states = model.predict(
#      89         observations,  # type: ignore[arg-type]
#      90         state=states,
#      91         episode_start=episode_starts,
#      92         deterministic=deterministic,
#      93     )
# ---> 94     new_observations, rewards, dones, infos = env.step(actions)
#      95     current_rewards += rewards
#      96     current_lengths += 1
#
# File ~\anaconda3\envs\RL\lib\site-packages\stable_baselines3\common\vec_env\base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~\anaconda3\envs\RL\lib\site-packages\stable_baselines3\common\vec_env\dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~\anaconda3\envs\RL\lib\site-packages\gymnasium\wrappers\time_limit.py:57, in TimeLimit.step(self, action)
#      46 def step(self, action):
#      47     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      48
#      49     Args:
#    (...)
#      55
#      56     """
# ---> 57     observation, reward, terminated, truncated, info = self.env.step(action)
#      58     self._elapsed_steps += 1
#      60     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~\anaconda3\envs\RL\lib\site-packages\gymnasium\wrappers\order_enforcing.py:56, in OrderEnforcing.step(self, action)
#      54 if not self._has_reset:
#      55     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 56 return self.env.step(action)
#
# File ~\anaconda3\envs\RL\lib\site-packages\gymnasium\wrappers\env_checker.py:51, in PassiveEnvChecker.step(self, action)
#      49     return env_step_passive_checker(self.env, action)
#      50 else:
# ---> 51     return self.env.step(action)
#
# File D:\ResearchLab\IRL\IRL_for_PdM\MT_environment.py:154, in MillingTool_Env_NUAA.step(self, action)
#     152 info = {'Step':'-'}
#     153 # Get auxilliary info: current RUL reading (note this is NOT part of the observation) and the expert's recommended action
# --> 154 recommended_action, self.rul = self._get_auxilliary_info()
#     155 self.maintenance_cost = 0.0
#     156 self.replacement_events += 0
#
# File D:\ResearchLab\IRL\IRL_for_PdM\MT_environment.py:113, in MillingTool_Env_NUAA._get_auxilliary_info(self)
#     110 if (self.df is not None):
#     111     # From database extract recommended action
#     112     recommended_action = int(self.df.loc[self.current_time_step, 'ACTION_CODE'])
# --> 113     rul =  float(self.df.loc[self.current_time_step, 'RUL'])
#     114 else:
#     115     # No database - use dummy values
#     116     recommended_action = 0
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\indexing.py:1097, in _LocationIndexer.__getitem__(self, key)
#    1095     if self._is_scalar_access(key):
#    1096         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1097     return self._getitem_tuple(key)
#    1098 else:
#    1099     # we by definition only have the 0th axis
#    1100     axis = self.axis or 0
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\indexing.py:1280, in _LocIndexer._getitem_tuple(self, tup)
#    1278 with suppress(IndexingError):
#    1279     tup = self._expand_ellipsis(tup)
# -> 1280     return self._getitem_lowerdim(tup)
#    1282 # no multi-index, so validate all of the indexers
#    1283 tup = self._validate_tuple_indexer(tup)
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\indexing.py:1000, in _LocationIndexer._getitem_lowerdim(self, tup)
#     996 for i, key in enumerate(tup):
#     997     if is_label_like(key):
#     998         # We don't need to check for tuples here because those are
#     999         #  caught by the _is_nested_tuple_indexer check above.
# -> 1000         section = self._getitem_axis(key, axis=i)
#    1002         # We should never have a scalar section here, because
#    1003         #  _getitem_lowerdim is only called after a check for
#    1004         #  is_scalar_access, which that would be.
#    1005         if section.ndim == self.ndim:
#    1006             # we're in the middle of slicing through a MultiIndex
#    1007             # revise the key wrt to `section` by inserting an _NS
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\indexing.py:1343, in _LocIndexer._getitem_axis(self, key, axis)
#    1341 # fall thru to straight lookup
#    1342 self._validate_key(key, axis)
# -> 1343 return self._get_label(key, axis=axis)
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\indexing.py:1293, in _LocIndexer._get_label(self, label, axis)
#    1291 def _get_label(self, label, axis: AxisInt):
#    1292     # GH#5567 this will fail if the label is not present in the axis.
# -> 1293     return self.obj.xs(label, axis=axis)
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\generic.py:4082, in NDFrame.xs(self, key, axis, level, drop_level)
#    4080 if axis == 1:
#    4081     if drop_level:
# -> 4082         return self[key]
#    4083     index = self.columns
#    4084 else:
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\anaconda3\envs\RL\lib\site-packages\pandas\core\indexes\base.py:3654, in Index.get_loc(self, key)
#    3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
# -> 3654     raise KeyError(key) from err
#    3655 except TypeError:
#    3656     # If we have a listlike key, _check_indexing_error will raise
#    3657     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3658     #  the TypeError.
#    3659     self._check_indexing_error(key)
#
# KeyError: 'RUL'

# %% [markdown]
# ```
# Run 1: 12-Oct-2024  07:48:11 : A2C, 8000, 4171.26
# Run 2: 12-Oct-2024  07:48:11 : A2C, 8000, 4167.74
# Run 3: 12-Oct-2024  09:01:08 : A2C, 8000, 4177.76
# ```
